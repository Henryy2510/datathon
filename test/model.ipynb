# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data
train = pd.read_csv('./datathon-2026-round-1/sales.csv')
test = pd.read_csv('./datathon-2026-round-1/sample_submission.csv')

# %%
train
# Out:
#             Date     Revenue        COGS
# 0     2012-07-04  5123547.94  3982991.19
# 1     2012-07-05  2751773.45  2150580.23
# 2     2012-07-06  3054029.42  2517632.84
# 3     2012-07-07  2667930.94  2108246.62
# 4     2012-07-08  2360851.90  1808622.79
# ...          ...         ...         ...
# 3828  2022-12-27  2100553.66  2184872.24
# 3829  2022-12-28  3448729.20  3513621.00
# 3830  2022-12-29  3083944.33  3170787.10
# 3831  2022-12-30  2884668.76  3022292.15
# 3832  2022-12-31  2383037.48  2279288.13
#
# [3833 rows x 3 columns]

# %%
X = train.drop(['Date', 'Revenue'], axis=1)
y = train['Revenue']
# The test set should use the same feature columns as training data.
# Drop Date and Revenue so only numeric features remain.
X_test = test.drop(['Date', 'Revenue'], axis=1)

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, random_state=88
)

# %%
# Setting parameters can help improve model performance.
model = xgb.XGBRegressor(
    n_estimators=500,
    learning_rate=0.01,
    max_depth=8,
    min_child_weight=6,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.1,
    reg_alpha=0.05,
    reg_lambda=1,
    random_state=42,
    n_jobs=-1,
    # Remove the following parameters as they are for classification, not regression:
    # objective='multi:softprob',
    # num_class=3,
    # eval_metric='mlogloss'
)
model.fit(X_train, y_train,
    eval_set=[(X_train, y_train), (X_val, y_val)],
    verbose=50)
# Out:
# [0]	validation_0-rmse:2632422.75165	validation_1-rmse:2466770.09133
# [50]	validation_0-rmse:1673470.80802	validation_1-rmse:1572316.43791
# [100]	validation_0-rmse:1116741.19268	validation_1-rmse:1065962.93036
# [150]	validation_0-rmse:812631.04734	validation_1-rmse:804728.13836
# [200]	validation_0-rmse:661897.13438	validation_1-rmse:686909.72522
# [250]	validation_0-rmse:595286.03625	validation_1-rmse:642356.99489
# [300]	validation_0-rmse:567648.85661	validation_1-rmse:627495.63805
# [350]	validation_0-rmse:556554.86011	validation_1-rmse:624156.83370
# [400]	validation_0-rmse:552065.79366	validation_1-rmse:623951.42362
# [450]	validation_0-rmse:550325.82944	validation_1-rmse:625054.55798
# [499]	validation_0-rmse:549577.06674	validation_1-rmse:625980.94717
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
# ...

# %%
# Evaluate on validation set
y_val_pred = model.predict(X_val)
val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
val_r2 = r2_score(y_val, y_val_pred)
print(f"Validation RMSE: {val_rmse:.2f}")
print(f"Validation R^2: {val_r2:.4f}")

# Evaluate on training set
y_train_pred = model.predict(X_train)
train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
train_r2 = r2_score(y_train, y_train_pred)
print(f"Training RMSE: {train_rmse:.2f}")
print(f"Training R^2: {train_r2:.4f}")
# Out:
# Validation RMSE: 625980.95
# Validation R^2: 0.9367
# Training RMSE: 549577.07
# Training R^2: 0.9572

# %%
y_test_pred = model.predict(X_test)
print(len(y_test_pred))
# Out:
# 548

# %% [markdown]
# # Random Forest

# %%
# Train Random Forest Regressor
rf_model = RandomForestRegressor(
    n_estimators=500,
    max_depth=10,
    min_samples_split=6,
    min_samples_leaf=4,
    max_features='sqrt',
    bootstrap=True,
    random_state=42,
    n_jobs=-1,
    verbose=1
)

rf_model.fit(X_train, y_train)
print("\nRandom Forest training completed!")
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    0.2s
# Random Forest training completed!
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:    0.3s finished

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Evaluate Random Forest model on validation set
rf_val_pred = rf_model.predict(X_val)
rf_val_rmse = np.sqrt(mean_squared_error(y_val, rf_val_pred))
rf_val_r2 = r2_score(y_val, rf_val_pred)
print(f"Random Forest Validation RMSE: {rf_val_rmse:.2f}")
print(f"Random Forest Validation R^2: {rf_val_r2:.4f}")

# Evaluate on training set
rf_train_pred = rf_model.predict(X_train)
rf_train_rmse = np.sqrt(mean_squared_error(y_train, rf_train_pred))
rf_train_r2 = r2_score(y_train, rf_train_pred)
print(f"Random Forest Training RMSE: {rf_train_rmse:.2f}")
print(f"Random Forest Training R^2: {rf_train_r2:.4f}")
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.1s
# Random Forest Validation RMSE: 655838.68
# Random Forest Validation R^2: 0.9305
# Random Forest Training RMSE: 487546.98
# Random Forest Training R^2: 0.9663
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.1s finished

# %%
# Random Forest predictions on test set
rf_test_pred = rf_model.predict(X_test)
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.1s finished

# %%
# Ensemble predictions - weighted average of XGBoost and Random Forest
xgb_weight = 0.5
rf_weight = 0.5

# Ensemble validation predictions
ensemble_val_pred = xgb_weight * y_val_pred + rf_weight * rf_val_pred

# Evaluate ensemble
ensemble_val_rmse = np.sqrt(mean_squared_error(y_val, ensemble_val_pred))
ensemble_val_r2 = r2_score(y_val, ensemble_val_pred)
print(f"Ensemble Validation RMSE: {ensemble_val_rmse:.2f}")
print(f"Ensemble Validation R^2: {ensemble_val_r2:.4f}")
# Out:
# Ensemble Validation RMSE: 636994.80
# Ensemble Validation R^2: 0.9345

# %%
# Compare model validation metrics side by side
comparison = pd.DataFrame({
    'Model': ['XGBoost', 'Random Forest', 'Ensemble'],
    'Validation_RMSE': [val_rmse, rf_val_rmse, ensemble_val_rmse],
    'Validation_R2': [val_r2, rf_val_r2, ensemble_val_r2]
})

print(comparison)
print()

# Plot comparison charts for the models
fig, axes = plt.subplots(1, 2, figsize=(14, 5), constrained_layout=True)
comparison.plot(x='Model', y='Validation_RMSE', kind='bar', ax=axes[0], color=['#1f77b4', '#ff7f0e', '#2ca02c'])
axes[0].set_title('Validation RMSE by Model')
axes[0].set_ylabel('RMSE')
axes[0].set_xlabel('')
axes[0].grid(axis='y', linestyle='--', alpha=0.5)

comparison.plot(x='Model', y='Validation_R2', kind='bar', ax=axes[1], color=['#1f77b4', '#ff7f0e', '#2ca02c'])
axes[1].set_title('Validation R² by Model')
axes[1].set_ylabel('R²')
axes[1].set_xlabel('')
axes[1].grid(axis='y', linestyle='--', alpha=0.5)

plt.show()

# Compare actual vs predicted validation outputs for the first 30 samples
val_index = y_val.reset_index(drop=True).index[:30]
predictions_df = pd.DataFrame({
    'Actual': y_val.reset_index(drop=True).iloc[:30],
    'XGBoost': y_val_pred[:30],
    'RandomForest': rf_val_pred[:30],
    'Ensemble': ensemble_val_pred[:30]
}, index=val_index)

fig, ax = plt.subplots(figsize=(14, 5))
predictions_df.plot(ax=ax, marker='o')
ax.set_title('First 30 Validation Predictions: XGBoost vs Random Forest vs Ensemble')
ax.set_xlabel('Validation sample index')
ax.set_ylabel('Revenue')
ax.grid(True, linestyle='--', alpha=0.5)
plt.legend(title='Series')
plt.show()
# Out:
#            Model  Validation_RMSE  Validation_R2
# 0        XGBoost    625980.946489       0.936728
# 1  Random Forest    655838.675281       0.930549
# 2       Ensemble    636994.803269       0.934482

# %%
# Ensemble predictions on test set (regression)
ensemble_test_pred = xgb_weight * y_test_pred + rf_weight * rf_test_pred

# Create ensemble submission file
ensemble_submission = pd.DataFrame({
    'Date': test['Date'],
    'Revenue': ensemble_test_pred
})

# Save ensemble submission
ensemble_submission.to_csv('./datathon-2026-round-1/submission.csv', index=False)
