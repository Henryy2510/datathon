# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Loading Data into a DataFrame(data)

data = pd.read_csv("./europe.csv")
data.head()
# Out:
#    Unnamed: 0   country_name Continent          region         local_name  \
# 0           0        Austria    Europe  Western Europe         Österreich
# 1           1        Belgium    Europe  Western Europe  België / Belgique
# 2           2         France    Europe  Western Europe             France
# 3           3        Germany    Europe  Western Europe        Deutschland
# 4           4  Liechtenstein    Europe  Western Europe      Liechtenstein
#
#     capital         area  population population_per_sq_km  \
# 0    Vienna   83,879 km²   8,917,000                106.3
# 1  Brussels   30,530 km²  11,544,000                378.1
# 2     Paris  549,087 km²  67,380,000                122.7
# 3    Berlin  357,580 km²  83,161,000                232.6
# 4     Vaduz      161 km²      38,137                237.6
#
#    male_life_expectancy  female_life_expectancy  birth_rate  death_rate
# 0                  78.9                    83.6         9.4        10.3
# ...

# %%
#Getting Rows and Col

print("No.of Rows : ",data.shape[0],"No .of col : ",data.shape[1])
# Out:
# No.of Rows :  36 No .of col :  13

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              36 non-null     int64
#  1   country_name            36 non-null     str
#  2   Continent               36 non-null     str
#  3   region                  36 non-null     str
#  4   local_name              36 non-null     str
#  5   capital                 36 non-null     str
#  6   area                    36 non-null     str
#  7   population              36 non-null     str
#  8   population_per_sq_km    36 non-null     str
#  9   male_life_expectancy    36 non-null     float64
#  10  female_life_expectancy  36 non-null     float64
#  11  birth_rate              36 non-null     float64
#  12  death_rate              36 non-null     float64
# dtypes: float64(4), int64(1), str(8)
# memory usage: 3.8 KB

# %%
#Checking for NULL values 

data.isna().any()
# Out:
# Unnamed: 0                False
# country_name              False
# Continent                 False
# region                    False
# local_name                False
# capital                   False
# area                      False
# population                False
# population_per_sq_km      False
# male_life_expectancy      False
# female_life_expectancy    False
# birth_rate                False
# death_rate                False
# dtype: bool

# %%
data.describe().style.highlight_max(color='lightgreen',axis=0)     #Stat for the dataset
# Out:
# <style type="text/css">
# #T_e92cd_row0_col0, #T_e92cd_row0_col3, #T_e92cd_row0_col4, #T_e92cd_row7_col1, #T_e92cd_row7_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e92cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e92cd_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_e92cd_level0_col1" class="col_heading level0 col1" >male_life_expectancy</th>
#       <th id="T_e92cd_level0_col2" class="col_heading level0 col2" >female_life_expectancy</th>
#       <th id="T_e92cd_level0_col3" class="col_heading level0 col3" >birth_rate</th>
#       <th id="T_e92cd_level0_col4" class="col_heading level0 col4" >death_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e92cd_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_e92cd_row0_col0" class="data row0 col0" >36.000000</td>
#       <td id="T_e92cd_row0_col1" class="data row0 col1" >36.000000</td>
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0                  int64
# country_name                  str
# Continent                     str
# region                        str
# local_name                    str
# capital                       str
# area                          str
# population                    str
# population_per_sq_km          str
# male_life_expectancy      float64
# female_life_expectancy    float64
# birth_rate                float64
# death_rate                float64
# dtype: object

# %%
#Datacleaning

data['population_per_sq_km2'] = data['population_per_sq_km'].str.replace(',','')

data['population_per_sq_km2'] = data['population_per_sq_km2'].astype(float)

data['population_per_sq_km2']
# Out:
# 0      106.300
# 1      378.100
# 2      122.700
# 3      232.600
# 4      237.600
# 5      243.400
# 6      419.800
# 7      209.200
# 8       45.180
# 9       62.470
# 10     135.600
# 11     104.800
# 12      77.410
# 13     121.200
# 14      80.780
# 15       8.428
# 16     111.300
# 17      73.130
# 18     135.900
# 19      29.320
# 20      16.340
# 21       3.558
# 22      70.940
# 23      29.470
# 24      42.810
# 25      13.970
# 26      23.140
# 27     275.900
# 28      98.710
# 29      81.090
# 30    1610.000
# 31      44.990
# 32     111.700
# 33      78.080
# 34     101.700
# 35      93.620
# Name: population_per_sq_km2, dtype: float64

# %%
#Datatypes

data.dtypes
# Out:
# Unnamed: 0                  int64
# country_name                  str
# Continent                     str
# region                        str
# local_name                    str
# capital                       str
# area                          str
# population                    str
# population_per_sq_km          str
# male_life_expectancy      float64
# female_life_expectancy    float64
# birth_rate                float64
# death_rate                float64
# population_per_sq_km2     float64
# dtype: object

# %%
sns.scatterplot(x=data['male_life_expectancy'],y=data['female_life_expectancy'])
# Out:
# <Axes: xlabel='male_life_expectancy', ylabel='female_life_expectancy'>

# %%
sns.scatterplot(x=data['birth_rate'],y=data['death_rate'])
# Out:
# <Axes: xlabel='birth_rate', ylabel='death_rate'>

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data['region'].value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
data['region'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='region'>

# %%
#Top 10 country with high male_life_expectancy

data.sort_values(by=['male_life_expectancy'],ascending=False).head(10)['country_name']
# Out:
# 21          Iceland
# 25           Norway
# 7       Switzerland
# 30            Malta
# 26           Sweden
# 22          Ireland
# 4     Liechtenstein
# 6       Netherlands
# 35            Spain
# 18          Denmark
# Name: country_name, dtype: str

# %%
#Top 10 country with high female_life_expectancy

data.sort_values(by=['female_life_expectancy'],ascending=False).head(10)['country_name']
# Out:
# 2          France
# 7     Switzerland
# 35          Spain
# 20        Finland
# 25         Norway
# 30          Malta
# 21        Iceland
# 26         Sweden
# 5      Luxembourg
# 32       Portugal
# Name: country_name, dtype: str

# %%
sns.pairplot(data)
plt.show()

# %%
new_index = (data.sort_values(by=['male_life_expectancy'],ascending=False).head(10)).index.values
sorted_data = data.reindex(new_index)

#Visualization

plt.figure(figsize=(15,15))
sns.barplot(x=sorted_data['country_name'],y=sorted_data['male_life_expectancy'])
# Out:
# <Axes: xlabel='country_name', ylabel='male_life_expectancy'>

# %%
new_index = (data.sort_values(by=['female_life_expectancy'],ascending=False).head(10)).index.values
sorted_data = data.reindex(new_index)

#Visualization

plt.figure(figsize=(15,15))
sns.barplot(x=sorted_data['country_name'],y=sorted_data['female_life_expectancy'])
# Out:
# <Axes: xlabel='country_name', ylabel='female_life_expectancy'>

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >
